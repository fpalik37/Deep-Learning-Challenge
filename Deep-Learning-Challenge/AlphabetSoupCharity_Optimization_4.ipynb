# %% [markdown]
# ## AlphabetSoupCharity_Optimization_4
#
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN"],1)
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
val_counts = application_df['APPLICATION_TYPE'].value_counts()

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=val_counts[val_counts < 500].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
val_counts = application_df['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
val_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace=val_counts[val_counts < 1500].index.tolist()#  YOUR CODE GOES HERE

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
val_counts = application_df['NAME'].value_counts()

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=val_counts[val_counts < 5].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(app,"Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                                                19803
# PARENT BOOSTER USA INC                                                1260
# TOPS CLUB INC                                                          765
# UNITED STATES BOWLING CONGRESS INC                                     700
# WASHINGTON STATE UNIVERSITY                                            492
#                                                                      ...
# GUILDS OF THE SANTA FE OPERA INC                                         5
# FAMILY MOTOR COACH ASSOCIATION                                           5
# JAMESTOWN SOCIETY                                                        5
# MOST WORSHIPFUL PRINCE HALL GRAND LODGE OF FREE & ACCEPTED MASONS        5
# PTA HAWAII CONGRESS                                                      5
# Name: NAME, Length: 403, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = dummies_df['IS_SUCCESSFUL'].values

# Separate the X variable, the features
x = dummies_df.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(x_train[0])
hidden_nodes_layer1 =  400
hidden_nodes_layer2 = 200
hidden_nodes_layer3 = 90

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# third hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 400)               178800
#
#  dense_1 (Dense)             (None, 200)               80200
#
#  dense_2 (Dense)             (None, 90)                18090
#
#  dense_3 (Dense)             (None, 1)                 91
#
# =================================================================
# Total params: 277181 (1.06 MB)
# Trainable params: 277181 (1.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
fit_model = nn.fit(x_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 12s 11ms/step - loss: 0.4652 - accuracy: 0.7800
# Epoch 2/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4327 - accuracy: 0.7942
# Epoch 3/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4249 - accuracy: 0.7977
# Epoch 4/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4223 - accuracy: 0.7964
# Epoch 5/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4195 - accuracy: 0.8006
# Epoch 6/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4199 - accuracy: 0.7990
# Epoch 7/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4178 - accuracy: 0.7996
# Epoch 8/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4175 - accuracy: 0.8010
# Epoch 9/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4159 - accuracy: 0.8008
# Epoch 10/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4156 - accuracy: 0.8016
# Epoch 11/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4148 - accuracy: 0.8016
# Epoch 12/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4143 - accuracy: 0.8017
# Epoch 13/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4135 - accuracy: 0.8026
# Epoch 14/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4121 - accuracy: 0.8031
# Epoch 15/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4123 - accuracy: 0.8042
# Epoch 16/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4114 - accuracy: 0.8045
# Epoch 17/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.4105 - accuracy: 0.8040
# Epoch 18/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4101 - accuracy: 0.8043
# Epoch 19/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4095 - accuracy: 0.8050
# Epoch 20/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4089 - accuracy: 0.8046
# Epoch 21/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4097 - accuracy: 0.8057
# Epoch 22/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4080 - accuracy: 0.8049
# Epoch 23/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4078 - accuracy: 0.8060
# Epoch 24/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4075 - accuracy: 0.8057
# Epoch 25/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4068 - accuracy: 0.8057
# Epoch 26/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4066 - accuracy: 0.8065
# Epoch 27/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4057 - accuracy: 0.8069
# Epoch 28/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.4055 - accuracy: 0.8064
# Epoch 29/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4052 - accuracy: 0.8065
# Epoch 30/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4052 - accuracy: 0.8063
# Epoch 31/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4043 - accuracy: 0.8072
# Epoch 32/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4043 - accuracy: 0.8077
# Epoch 33/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4044 - accuracy: 0.8067
# Epoch 34/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4040 - accuracy: 0.8068
# Epoch 35/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4034 - accuracy: 0.8069
# Epoch 36/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4030 - accuracy: 0.8079
# Epoch 37/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4024 - accuracy: 0.8085
# Epoch 38/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4023 - accuracy: 0.8086
# Epoch 39/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4023 - accuracy: 0.8085
# Epoch 40/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4024 - accuracy: 0.8084
# Epoch 41/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4018 - accuracy: 0.8090
# Epoch 42/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4030 - accuracy: 0.8078
# Epoch 43/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4013 - accuracy: 0.8080
# Epoch 44/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4011 - accuracy: 0.8089
# Epoch 45/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4015 - accuracy: 0.8087
# Epoch 46/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4005 - accuracy: 0.8085
# Epoch 47/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4008 - accuracy: 0.8088
# Epoch 48/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.4006 - accuracy: 0.8085
# Epoch 49/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3999 - accuracy: 0.8096
# Epoch 50/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4000 - accuracy: 0.8094
# Epoch 51/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4002 - accuracy: 0.8093
# Epoch 52/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4004 - accuracy: 0.8090
# Epoch 53/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3999 - accuracy: 0.8093
# Epoch 54/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3996 - accuracy: 0.8082
# Epoch 55/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3996 - accuracy: 0.8090
# Epoch 56/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3994 - accuracy: 0.8094
# Epoch 57/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3993 - accuracy: 0.8097
# Epoch 58/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3997 - accuracy: 0.8092
# Epoch 59/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3995 - accuracy: 0.8091
# Epoch 60/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3997 - accuracy: 0.8088
# Epoch 61/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3987 - accuracy: 0.8090
# Epoch 62/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3997 - accuracy: 0.8087
# Epoch 63/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3990 - accuracy: 0.8095
# Epoch 64/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3991 - accuracy: 0.8092
# Epoch 65/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3997 - accuracy: 0.8094
# Epoch 66/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3990 - accuracy: 0.8087
# Epoch 67/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3985 - accuracy: 0.8091
# Epoch 68/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3982 - accuracy: 0.8098
# Epoch 69/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.3985 - accuracy: 0.8099
# Epoch 70/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3993 - accuracy: 0.8097
# Epoch 71/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3988 - accuracy: 0.8092
# Epoch 72/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3985 - accuracy: 0.8097
# Epoch 73/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3980 - accuracy: 0.8095
# Epoch 74/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3985 - accuracy: 0.8093
# Epoch 75/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.3983 - accuracy: 0.8093
# Epoch 76/100
# 804/804 [==============================] - 15s 18ms/step - loss: 0.3985 - accuracy: 0.8096
# Epoch 77/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3984 - accuracy: 0.8099
# Epoch 78/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3980 - accuracy: 0.8097
# Epoch 79/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3982 - accuracy: 0.8100
# Epoch 80/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3983 - accuracy: 0.8099
# Epoch 81/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3978 - accuracy: 0.8099
# Epoch 82/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3975 - accuracy: 0.8099
# Epoch 83/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3975 - accuracy: 0.8098
# Epoch 84/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3974 - accuracy: 0.8102
# Epoch 85/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3977 - accuracy: 0.8099
# Epoch 86/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3977 - accuracy: 0.8111
# Epoch 87/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3977 - accuracy: 0.8104
# Epoch 88/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3977 - accuracy: 0.8104
# Epoch 89/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3977 - accuracy: 0.8104
# Epoch 90/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3977 - accuracy: 0.8104
# Epoch 91/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3973 - accuracy: 0.8104
# Epoch 92/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3980 - accuracy: 0.8104
# Epoch 93/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3976 - accuracy: 0.8103
# Epoch 94/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.3974 - accuracy: 0.8107
# Epoch 95/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.3975 - accuracy: 0.8101
# Epoch 96/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3972 - accuracy: 0.8102
# Epoch 97/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3981 - accuracy: 0.8103
# Epoch 98/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3976 - accuracy: 0.8104
# Epoch 99/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3978 - accuracy: 0.8101
# Epoch 100/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.3975 - accuracy: 0.8104

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.4594 - accuracy: 0.7925 - 820ms/epoch - 3ms/step
# Loss: 0.4594085216522217, Accuracy: 0.7925364375114441

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity_Optimization_4.h5')
